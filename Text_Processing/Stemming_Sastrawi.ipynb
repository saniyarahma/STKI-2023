# %%
import pandas as pd

# %%
dataset = pd.read_csv('sentimen_film_clean_dataset.csv', sep=';')

# %%
dataset.head()
# Out:
#    Unnamed: 0 Sentiment                                         Text Tweet  \
# 0           0  negative  Jelek filmnya... apalagi si ernest gak mutu bg...
# 1           1  negative  Film king Arthur ini film paling jelek dari se...
# 2           2  negative  @beexkuanlin Sepanjang film gwa berkata kasar ...
# 3           3  negative  Ane ga suka fast and furious..menurutku kok je...
# 4           4  negative  @baekhyun36 kan gua ga tau film nya, lu bilang...
#
#                                               step01  \
# 0  jelek filmnya apalagi si ernest gak mutu bgt a...
# 1  film king arthur ini film paling jelek dari se...
# 2  bee sepanjang film gwa berkata kasar terus pad...
# 3  ane ga suka fast and furious menurutku kok jel...
# 4  baekhyun kan gua ga tau film nya lu bilang per...
#
#                                               tokens  \
# 0  ['jelek', 'filmnya', 'apalagi', 'si', 'ernest'...
# 1  ['film', 'king', 'arthur', 'ini', 'film', 'pal...
# 2  ['bee', 'sepanjang', 'film', 'gwa', 'berkata',...
# 3  ['ane', 'ga', 'suka', 'fast', 'and', 'furious'...
# 4  ['baekhyun', 'kan', 'gua', 'ga', 'tau', 'film'...
#
#                                         final_tokens  \
# 0  ['jelek', 'filmnya', 'apalagi', 'si', 'ernest'...
# 1  ['film', 'king', 'arthur', 'ini', 'film', 'pal...
# 2  ['bee', 'sepanjang', 'film', 'gwa', 'berkata',...
# 3  ['ane', 'ga', 'suka', 'fast', 'and', 'furious'...
# 4  ['baekhyun', 'kan', 'gua', 'ga', 'tau', 'film'...
#
#                                               step02
# 0  jelek filmnya apalagi si ernest gak mutu bgt a...
# 1  film king arthur ini film paling jelek dari se...
# 2  bee sepanjang film gwa berkata kasar terus pad...
# 3  ane ga suka fast and furious menurutku kok jel...
# 4  baekhyun kan gua ga tau film nya lu bilang per...

# %%
# !pip install Sastrawi
# Out:
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      -------------------------------------- 209.7/209.7 kB 2.6 MB/s eta 0:00:00
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory, StopWordRemover, ArrayDictionary
 
factory = StopWordRemoverFactory()

more_stopword = ['sih', 'nya','rt','loh','lah', 'dd', 'mah', 'nye', 'eh', 'ehh', 'ah', 'yang','yg']
 
# Tambahkan Stopword Baru
data = factory.get_stop_words()+more_stopword

stopwords_sastrawi = factory.create_stop_word_remover()

dictionary = ArrayDictionary(data)
str_stopwords = StopWordRemover(dictionary)

# %%
dataset['finalText_str'] = dataset['step02'].apply(str)

# %%
i=0
final_string = []
s = ""
for sentence in dataset["finalText_str"].values:
    filteredSentence = []
    EachReviewText = ""
    st = str_stopwords.remove(sentence)
    s = (stemmer.stem(st))
    filteredSentence.append(s)
    
    EachReviewText = ' '.join(filteredSentence)
    final_string.append(EachReviewText)

# %%
dataset.loc[:, ('ProcessedText')] = final_string

# %%
dataset
# Out:
#      Unnamed: 0 Sentiment                                         Text Tweet  \
# 0             0  negative  Jelek filmnya... apalagi si ernest gak mutu bg...
# 1             1  negative  Film king Arthur ini film paling jelek dari se...
# 2             2  negative  @beexkuanlin Sepanjang film gwa berkata kasar ...
# 3             3  negative  Ane ga suka fast and furious..menurutku kok je...
# 4             4  negative  @baekhyun36 kan gua ga tau film nya, lu bilang...
# ..          ...       ...                                                ...
# 195         195  positive  Fargo juga adaptasi dari film yang cukup berha...
# 196         196  positive  637.000 waw ini sangat keren flm horor dng jum...
# 197         197  positive  @filmziarah film yang tenang dan menghanyutkan...
# 198         198  positive  Film yg amat menarik. Kisah cinta & kesetiaan ...
# 199         199  positive  Nntn @filmziarah , film bagus, ada kali 5 meni...
#
#                                                 step01  \
# 0    jelek filmnya apalagi si ernest gak mutu bgt a...
# 1    film king arthur ini film paling jelek dari se...
# 2    bee sepanjang film gwa berkata kasar terus pad...
# 3    ane ga suka fast and furious menurutku kok jel...
# 4    baekhyun kan gua ga tau film nya lu bilang per...
# ..                                                 ...
# 195  fargo juga adaptasi dari film yang cukup berha...
# 196      waw ini sangat keren flm horor dng jumlah ...
# 197  filmziarah film yang tenang dan menghanyutkan ...
# 198  film yg amat menarik kisah cinta kesetiaan yg ...
# 199  nntn filmziarah film bagus ada kali   menit pe...
#
#                                                 tokens  \
# 0    ['jelek', 'filmnya', 'apalagi', 'si', 'ernest'...
# 1    ['film', 'king', 'arthur', 'ini', 'film', 'pal...
# 2    ['bee', 'sepanjang', 'film', 'gwa', 'berkata',...
# 3    ['ane', 'ga', 'suka', 'fast', 'and', 'furious'...
# 4    ['baekhyun', 'kan', 'gua', 'ga', 'tau', 'film'...
# ..                                                 ...
# 195  ['fargo', 'juga', 'adaptasi', 'dari', 'film', ...
# 196  ['waw', 'ini', 'sangat', 'keren', 'flm', 'horo...
# 197  ['filmziarah', 'film', 'yang', 'tenang', 'dan'...
# 198  ['film', 'yg', 'amat', 'menarik', 'kisah', 'ci...
# 199  ['nntn', 'filmziarah', 'film', 'bagus', 'ada',...
#
#                                           final_tokens  \
# 0    ['jelek', 'filmnya', 'apalagi', 'si', 'ernest'...
# 1    ['film', 'king', 'arthur', 'ini', 'film', 'pal...
# 2    ['bee', 'sepanjang', 'film', 'gwa', 'berkata',...
# 3    ['ane', 'ga', 'suka', 'fast', 'and', 'furious'...
# 4    ['baekhyun', 'kan', 'gua', 'ga', 'tau', 'film'...
# ..                                                 ...
# 195  ['fargo', 'juga', 'adaptasi', 'dari', 'film', ...
# 196  ['waw', 'ini', 'sangat', 'keren', 'flm', 'horo...
# 197  ['filmziarah', 'film', 'yang', 'tenang', 'dan'...
# 198  ['film', 'yg', 'amat', 'menarik', 'kisah', 'ci...
# 199  ['nntn', 'filmziarah', 'film', 'bagus', 'ada',...
#
#                                                 step02  \
# 0    jelek filmnya apalagi si ernest gak mutu bgt a...
# 1    film king arthur ini film paling jelek dari se...
# 2    bee sepanjang film gwa berkata kasar terus pad...
# 3    ane ga suka fast and furious menurutku kok jel...
# 4    baekhyun kan gua ga tau film nya lu bilang per...
# ..                                                 ...
# 195  fargo juga adaptasi dari film yang cukup berha...
# 196  waw ini sangat keren flm horor dng jumlah peno...
# 197  filmziarah film yang tenang dan menghanyutkan ...
# 198  film yg amat menarik kisah cinta kesetiaan yg ...
# 199  nntn filmziarah film bagus ada kali menit peno...
#
#                                          finalText_str  \
# 0    jelek filmnya apalagi si ernest gak mutu bgt a...
# 1    film king arthur ini film paling jelek dari se...
# 2    bee sepanjang film gwa berkata kasar terus pad...
# 3    ane ga suka fast and furious menurutku kok jel...
# 4    baekhyun kan gua ga tau film nya lu bilang per...
# ..                                                 ...
# 195  fargo juga adaptasi dari film yang cukup berha...
# 196  waw ini sangat keren flm horor dng jumlah peno...
# 197  filmziarah film yang tenang dan menghanyutkan ...
# 198  film yg amat menarik kisah cinta kesetiaan yg ...
# 199  nntn filmziarah film bagus ada kali menit peno...
#
#                                          ProcessedText
# 0    jelek film si ernest gak mutu bgt actingnya fi...
# 1    film king arthur film paling jelek seluruh cer...
# 2          bee panjang film gwa kata kasar terus bapak
# 3    ane ga suka fast and furious turut kok jelek t...
# 4    baekhyun kan gua ga tau film lu bilang perang ...
# ..                                                 ...
# 195  fargo adaptasi film cukup hasil season the bes...
# 196  waw sangat keren flm horor dng jumlah tonton g...
# 197  filmziarah film tenang hanyut salut mbah ponco...
# 198  film amat tarik kisah cinta setia saji tidak b...
# 199  nntn filmziarah film bagus kali menit tonton g...
#
# [200 rows x 9 columns]

# %%
dataset.to_csv('clean_dataset_film_stem.csv',sep=';')
