# %% [markdown]
# ## Text Summarization - (tf-idf)
#
# #### STEP 1 : Data cleaning
# #### STEP 2 : Score of sentences (tf-idf)
# #### STEP 3 : Summary Generation

# %% [markdown]
# ## Initial Phase
# ### Importing Libraries and Reading Data

# %%
### importing the necessary libraries

from nltk.corpus import stopwords
import numpy as np
import pandas
import nltk
import re
# from __future__ import division

# %%
df = pandas.read_csv('Tweets.csv')

# %%
print(df['text'])

for a in df['text']:
    print(len(a))
# Out:
# 0                      I`d have responded, if I were going
# 1            Sooo SAD I will miss you here in San Diego!!!
# 2                                my boss is bullying me...
# 3                           what interview! leave me alone
# 4         Sons of ****, why couldn`t they put them on t...
#                                ...
# 27476     wish we could come see u on Denver  husband l...
# 27477     I`ve wondered about rake to.  The client has ...
# 27478     Yay good for both of you. Enjoy the break - y...
# 27479                           But it was worth it  ****.
# 27480       All this flirting going on - The ATG smiles...
# Name: text, Length: 27481, dtype: object
# 36
# 46
# 25
# 31
# 75
# 92
# 64
# 10
# 12
# 69
# 107
# 56
# 44
# 50
# 26
# 21
# 53
# 137
# 42
# 26
# 59
# 135
# 65
# 98
# 79
# 51
# 12
# 51
# 109
# 78
# 84
# 58
# 126
# 31
# 102
# 84
# 82
# 123
# 72
# 89
# 107
# 57
# 8
# 138
# 102
# 84
# 89
# 36
# 126
# 77
# 98
# 60
# 28
# 56
# 22
# 55
# 87
# 45
# 34
# 30
# 60
# 9
# 19
# 135
# 66
# 19
# 70
# 85
# 8
# 39
# 36
# 60
# 115
# 81
# 120
# 125
# 50
# 18
# 15
# 69
# 32
# 57
# 32
# 28
# 108
# 56
# 124
# 131
# 68
# 120
# 50
# 45
# 52
# 75
# 55
# 43
# 125
# 45
# 66
# 47
# 32
# 32
# 136
# 62
# 123
# 50
# 49
# 112
# 71
# 33
# 126
# 21
# 65
# 126
# 102
# 57
# 64
# 22
# 47
# 120
# 54
# 134
# 95
# 102
# 8
# 15
# 61
# 11
# 29
# 63
# 115
# 54
# 85
# 17
# 117
# 127
# 111
# 104
# 30
# 59
# 135
# 67
# 136
# 72
# 13
# 80
# 41
# 46
# 29
# 122
# 124
# 101
# 37
# 51
# 58
# 31
# 11
# 104
# 49
# 73
# 26
# 28
# 32
# 123
# 23
# 79
# 79
# 94
# 45
# 97
# 13
# 24
# 110
# 120
# 70
# 48
# 61
# 31
# 49
# 105
# 51
# 62
# 127
# 43
# 58
# 8
# 14
# 97
# 89
# 48
# 16
# 129
# 73
# 50
# 64
# 14
# 49
# 41
# 132
# 91
# 52
# 60
# 39
# 28
# 118
# 41
# 43
# 47
# 82
# 31
# 53
# 31
# 101
# 58
# 67
# 36
# 91
# 26
# 10
# 109
# 44
# 15
# 107
# 62
# 8
# 135
# 88
# 51
# 123
# 87
# 55
# 98
# 135
# 21
# 101
# 54
# 83
# 31
# 4
# 42
# 63
# 134
# 67
# 33
# 61
# 38
# 124
# 50
# 72
# 29
# 38
# 92
# 124
# 105
# 135
# 64
# 25
# 111
# 137
# 77
# 107
# 83
# 55
# 120
# 132
# 56
# 16
# 76
# 137
# 11
# 78
# 9
# 52
# 131
# 72
# 117
# 19
# 120
# 8
# 24
# 70
# 19
# 137
# 51
# 24
# 110
# 109
# 31
# 136
# 40
# 74
# 49
# 120
# 100
# 32
# 82
# 43
# 44
# 90
# 45
# 41
# 64
# 14
# 137
# 42
# 56
# 41
# 103
# 41
# 38
# 102
# 16
# 39
# 107
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 print(df['text'])
#       3 for a in df['text']:
# ----> 4     print(len(a))
#
# TypeError: object of type 'float' has no len()

# %% [markdown]
# ### Tokenizing sentences into words which would be used for calculating tf-idf scores

# %%
import pandas as pd
from nltk.tokenize import sent_tokenize

s = ""
for a in df['text']:
    if not pd.isnull(a):  # Check for NaN values
        s += str(a)

sentences = sent_tokenize(s)

# %% [markdown]
# ## STEP 1 : Data Cleaning
# ### Cleaning sentences, by removing Non Alphabet Characters and converting to Lower Case Letters

# %%
### pre processes the sentences by removing non alphabet characters and converting them to lower case letters 
### and stored in variable text

dict = {}
text=""
for a in sentences:
    temp = re.sub("[^a-zA-Z]"," ",a)
    temp = temp.lower()
    dict[temp] = a
    text+=temp
text
# Out:
# ' i d have responded  if i were going sooo sad i will miss you here in san diego   my boss is bullying me    what interview leave me alone sons of       why couldn t they put them on the releases we already boughthttp   www dothebouncy com smf   some shameless plugging for the best rangers forum on earth am feedings for the baby are fun when he is all smiles and coossoooo high both of you journey  wow    u just became cooler hehe     is that possible   as much as i love to be hopeful  i reckon the chances are minimal  p i m never gonna get my cake and stuffi really really like the song love story by taylor swiftmy sharpie is running dangerously low on inki want to go to music tonight but i lost my voice test test from the lg env uh oh  i am sunburned s ok  trying to plot alternatives as we speak  sigh i ve been sick for the past few days  and thus  my hair looks wierd if i didnt have a hat on it would look    http   tinyurl com mnf kwis back home now      gonna miss every onehes just not that into you oh marly  i m so sorry  i hope you find her soon       playing ghost online is really interesting the new updates are kirin pet and metamorph for third job can t wait to have a dragon petis cleaning the house for her family who is comming later today  gotta restart my computer   i thought win  was supposed to put an end to the constant rebootinesssee wat i mean bout foll w friidays    it s called lose f llowers friday    smhthe free fillin  app on my ipod is fun  im addicted  i m sorry on the way to malaysia   no internet access to twitjuss came backk from berkeleyy   omg its madd fun out there  havent been out there in a minute  whassqoodd  went to sleep and there is a power cut in noida  power back up not working tooi m going home now have you seen my new twitter design quite    heavenly isn      i hope unni will make the audition  fighting dahye unni  if it is any consolation i got my bmi tested hahaha it says i am obesed  well so much for being unhappy for about    minutes that s very funny cute kids ahhh  i slept through the game i m gonna try my best to watch tomorrow though i hope we play army thats it  its the end tears for fears vs eric prydz  dj hero   http   bit ly  hpbg born and raised in nyc and living in texas for the past    years i still miss nyjust in case you wonder  we are really busy today and this coming with with adding tons of new blogs and updates stay tunedi m soooooo sleeeeepy   the last day o  school was today    sniffle    a little happy for the wine jeje ok it sm my free time so who cares  jaja i love this day car not happy  big big dent in boot hoping theyre not going to write it off  crossing fingers and waitingim an avid fan of      magazine and i love your magazinesmayday  ratt rocked nashville tonite  one thing sucked  no encore like in the    s they still have a fun show pearcy has that hott bad boy look i love to but i m only available from  pm and where dear would love to help  convert her vids    the girl in the hair salon asked me  shall i trim your eyebrows  how old do i feel egh blah and boooooooooooo i dunno wanna go to work  hangovers suckkkkkk im a drunk mess  visiting my friendster and facebooki donbt like to peel prawns  i also dont like going shopping  running out of money and crawling round the car looking for more which case i got a new one last week and i m not thrilled at all with mine then you should check out http   twittersucks com and connect with other tweeple who hate twitter also bored at school  its my third freelesson  freistunde   hm   both of us i guess    it is        u have dissappointed me that past few days romance zero is funny i d rather do the early run  but i am a morning runnerbah a coworker ran into work late and her bag smacked into my knee  it really hurts nowwill be back later http   plurk com p rp k aw torn ace of hearts   hunchback what fun are you speaking of i lost all my friends  i m alone and sleepy  i wanna go home haha yesi give in to easilywhat be ...

# %% [markdown]
# ## STEP 2 : Getting tf-idf score of sentences
# ### Finding term frequency ( tf ) of words found in text

# %%
### calculated the frequency of the words found in text

stopwords = nltk.corpus.stopwords.words('english')
word_frequencies = {}
for word in nltk.word_tokenize(text):
    if word not in stopwords:
        if word not in word_frequencies.keys():
            word_frequencies[word] = 1
        else:
            word_frequencies[word] += 1
print (word_frequencies)
# Out:
# {'responded': 1, 'going': 1014, 'sooo': 105, 'sad': 424, 'miss': 616, 'san': 20, 'diego': 10, 'boss': 22, 'bullying': 1, 'interview': 27, 'leave': 136, 'alone': 77, 'sons': 5, 'put': 150, 'releases': 2, 'already': 226, 'boughthttp': 1, 'www': 121, 'dothebouncy': 1, 'com': 884, 'smf': 1, 'shameless': 1, 'plugging': 3, 'best': 306, 'rangers': 3, 'forum': 9, 'earth': 21, 'feedings': 1, 'baby': 157, 'fun': 512, 'smiles': 11, 'coossoooo': 1, 'high': 72, 'journey': 11, 'wow': 162, 'u': 967, 'became': 10, 'cooler': 6, 'hehe': 73, 'possible': 23, 'much': 644, 'love': 1122, 'hopeful': 7, 'reckon': 6, 'chances': 5, 'minimal': 2, 'p': 234, 'never': 291, 'gon': 429, 'na': 693, 'get': 1429, 'cake': 55, 'stuffi': 1, 'really': 886, 'like': 1346, 'song': 163, 'story': 46, 'taylor': 27, 'swiftmy': 1, 'sharpie': 1, 'running': 75, 'dangerously': 1, 'low': 35, 'inki': 1, 'want': 715, 'go': 1262, 'music': 146, 'tonight': 442, 'lost': 148, 'voice': 30, 'test': 63, 'lg': 4, 'env': 1, 'uh': 19, 'oh': 611, 'sunburned': 7, 'ok': 251, 'trying': 199, 'plot': 4, 'alternatives': 2, 'speak': 18, 'sigh': 63, 'sick': 229, 'past': 60, 'days': 320, 'thus': 5, 'hair': 147, 'looks': 200, 'wierd': 2, 'didnt': 115, 'hat': 14, 'would': 509, 'look': 256, 'http': 1135, 'tinyurl': 166, 'mnf': 1, 'kwis': 1, 'back': 848, 'home': 660, 'every': 116, 'onehes': 1, 'marly': 1, 'sorry': 468, 'hope': 599, 'find': 227, 'soon': 279, 'playing': 110, 'ghost': 10, 'online': 89, 'interesting': 56, 'new': 729, 'updates': 40, 'kirin': 1, 'pet': 11, 'metamorph': 1, 'third': 21, 'job': 166, 'wait': 325, 'dragon': 6, 'petis': 1, 'cleaning': 50, 'house': 227, 'family': 144, 'comming': 2, 'later': 158, 'today': 1030, 'got': 1194, 'ta': 163, 'restart': 2, 'computer': 76, 'thought': 208, 'win': 87, 'supposed': 66, 'end': 131, 'constant': 9, 'rebootinesssee': 1, 'wat': 25, 'mean': 136, 'bout': 57, 'foll': 1, 'w': 228, 'friidays': 1, 'called': 86, 'lose': 25, 'f': 60, 'llowers': 1, 'friday': 205, 'smhthe': 1, 'free': 116, 'fillin': 1, 'app': 35, 'ipod': 59, 'im': 824, 'addicted': 14, 'way': 398, 'malaysia': 3, 'internet': 85, 'access': 24, 'twitjuss': 1, 'came': 97, 'backk': 2, 'berkeleyy': 1, 'omg': 149, 'madd': 2, 'havent': 47, 'minute': 29, 'whassqoodd': 1, 'went': 200, 'sleep': 388, 'power': 30, 'cut': 54, 'noida': 2, 'working': 258, 'tooi': 4, 'seen': 112, 'twitter': 500, 'design': 25, 'quite': 89, 'heavenly': 4, 'unni': 2, 'make': 449, 'audition': 7, 'fighting': 15, 'dahye': 1, 'consolation': 3, 'bmi': 1, 'tested': 2, 'hahaha': 101, 'says': 90, 'obesed': 1, 'well': 652, 'unhappy': 8, 'minutes': 90, 'funny': 127, 'cute': 122, 'kids': 116, 'ahhh': 39, 'slept': 44, 'game': 130, 'try': 176, 'watch': 229, 'tomorrow': 471, 'though': 371, 'play': 164, 'army': 9, 'thats': 155, 'tears': 13, 'fears': 3, 'vs': 14, 'eric': 11, 'prydz': 1, 'dj': 17, 'hero': 17, 'bit': 381, 'ly': 186, 'hpbg': 1, 'born': 16, 'raised': 4, 'nyc': 28, 'living': 44, 'texas': 15, 'years': 102, 'still': 660, 'nyjust': 1, 'case': 33, 'wonder': 38, 'busy': 92, 'coming': 159, 'adding': 13, 'tons': 13, 'blogs': 4, 'stay': 99, 'tunedi': 1, 'soooooo': 14, 'sleeeeepy': 1, 'last': 572, 'day': 2019, 'school': 327, 'sniffle': 5, 'little': 295, 'happy': 783, 'wine': 38, 'jeje': 2, 'sm': 4, 'time': 895, 'cares': 6, 'jaja': 2, 'car': 165, 'big': 198, 'dent': 2, 'boot': 14, 'hoping': 69, 'theyre': 3, 'write': 60, 'crossing': 9, 'fingers': 38, 'waitingim': 1, 'avid': 2, 'fan': 71, 'magazine': 8, 'magazinesmayday': 1, 'ratt': 1, 'rocked': 13, 'nashville': 5, 'tonite': 28, 'one': 968, 'thing': 300, 'sucked': 17, 'encore': 2, 'show': 276, 'pearcy': 1, 'hott': 6, 'bad': 455, 'boy': 77, 'available': 27, 'pm': 79, 'dear': 60, 'help': 153, 'convert': 4, 'vids': 6, 'girl': 216, 'salon': 3, 'asked': 22, 'shall': 36, 'trim': 1, 'eyebrows': 3, 'old': 221, 'feel': 514, 'egh': 1, 'blah': 20, 'boooooooooooo': 1, 'dunno': 26, 'wan': 251, 'work': 1063, 'hangovers': 2, 'suckkkkkk': 1, 'drunk': 45, 'mess': 23, 'visiting': 12, 'friendster': 10, 'facebooki': 1 ...

# %% [markdown]
# ### Finding weighted frequency of the words

# %%
### finding weighted frequency of the words

max_freq = max(word_frequencies.values())

for w in word_frequencies :
      word_frequencies[w]/=max_freq
# print word_frequencies

# %% [markdown]
# ### Calculating sentence scores from the word frequncies

# %%
## calculating sentence scores from the word frequncies

sentence_scores = {}
for sent in sentences:
    for word in nltk.word_tokenize(sent.lower()):
        if word in word_frequencies.keys():
            if len(sent.split(' ')) < 30:
                if sent not in sentence_scores.keys():
                    sentence_scores[sent] = word_frequencies[word]
                else:
                    sentence_scores[sent] += word_frequencies[word]

# %% [markdown]
# ## STEP 3 : Summary Generation
# ### Outputting the top 17 sentences as the summary

# %%
### getting the summary by taking top score sentences

import heapq
summary_sentences = heapq.nlargest(17, sentence_scores, key=sentence_scores.get)
summary = ' '.join(summary_sentences)

# %%
summary_sentences
# Out:
# ['lol.',
#  'Hope u have a great wonderful day today   im happy cuz today is my last day of classes!!',
#  'we didn`t see you.Date Like A Man So You Dont Get Played Like A **** Good Luck.. mine 3rd day today !The hair looks sicckkkk.',
#  'happy mothers day!1st day of work today was a bit tiring but ok lol now onto college work Wow, you mom has a lot of energy.',
#  'Thanks!',
#  'oo never played it  thats so good that u like 2 play games most females dont like tooReady to crash!...had a great day and a FUN night!',
#  'I do hope I get to be a leader some day :/just got back from my exam... im surely gonna fail...now trying 2 get tickets 4 il divo!',
#  'You 2 going to shop a bit ?home from STING..crunk (of course)..long **** day N nite..also, visited my boy Rob V..all is good..happy mother`s day!',
#  'Another GloOmy day in NYC!last day off... back to work tomorrow Hey, it`s good to see you here!',
#  'morning  hope u r well.. i`m off to bed soon!going to bed happy mothers day peopleYes, he`s really back!',
#  'Happy Mother`s Day!',
#  'Good night yes LOL that`s good one .remeber that bottoms are always the top .Still awake lol Finished talking to a really good Brawl player.',
#  'Happy Mothers Day!',
#  'I love love love confit duckoff to glue stuff onto posterBeautiful Day..takn it down twitters  tell ALL mothers Happy Mothers Day Likewise.',
#  'Maybe one day ill get one too.HMV opens in half an our...better go get ready ugh!',
#  'Happy Star Wars Day!',
#  'And yes, that`s a Bollywood thing at the endAlready know I`m gonna miss josh next week.. My mom needs more surgery.. Work sucks.. Not a good day.']

# %%
summary
# Out:
# 'lol. Hope u have a great wonderful day today   im happy cuz today is my last day of classes!! we didn`t see you.Date Like A Man So You Dont Get Played Like A **** Good Luck.. mine 3rd day today !The hair looks sicckkkk. happy mothers day!1st day of work today was a bit tiring but ok lol now onto college work Wow, you mom has a lot of energy. Thanks! oo never played it  thats so good that u like 2 play games most females dont like tooReady to crash!...had a great day and a FUN night! I do hope I get to be a leader some day :/just got back from my exam... im surely gonna fail...now trying 2 get tickets 4 il divo! You 2 going to shop a bit ?home from STING..crunk (of course)..long **** day N nite..also, visited my boy Rob V..all is good..happy mother`s day! Another GloOmy day in NYC!last day off... back to work tomorrow Hey, it`s good to see you here! morning  hope u r well.. i`m off to bed soon!going to bed happy mothers day peopleYes, he`s really back! Happy Mother`s Day! Good night yes LOL that`s good one .remeber that bottoms are always the top .Still awake lol Finished talking to a really good Brawl player. Happy Mothers Day! I love love love confit duckoff to glue stuff onto posterBeautiful Day..takn it down twitters  tell ALL mothers Happy Mothers Day Likewise. Maybe one day ill get one too.HMV opens in half an our...better go get ready ugh! Happy Star Wars Day! And yes, that`s a Bollywood thing at the endAlready know I`m gonna miss josh next week.. My mom needs more surgery.. Work sucks.. Not a good day.'

# %%
len(summary)
# Out:
# 1534
